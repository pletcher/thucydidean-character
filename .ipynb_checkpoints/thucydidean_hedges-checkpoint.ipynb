# %%
from MyCapytain.resources.texts.local.capitains.cts import CapitainsCtsText
from MyCapytain.common.constants import Mimetypes
import polars as pl
import spacy

SPACY_MODEL = "grc_proiel_trf"

nlp = spacy.load(SPACY_MODEL)

SPEECHES = pl.read_csv("./thuc-speeches.tsv", separator="\t").with_columns(
    pl.col("start", "end").str.split(".").cast(pl.List(pl.UInt32)),
    pl.int_range(pl.len(), dtype=pl.UInt32).alias("index"),
)

THUCYDIDES_PARQUET = "thucydides.parquet"

def get_speech_for_ref(ref: list[int]):
    for speech in SPEECHES.iter_rows(named=True):
        ref_is_after_speech_start = True
        ref_is_before_speech_end = True

        for pair in zip(speech["start"], ref):
            if pair[0] > pair[1]:
                ref_is_after_speech_start = False

        for pair in zip(speech["end"], ref):
            if pair[0] < pair[1]:
                ref_is_before_speech_end = False

        if ref_is_after_speech_start and ref_is_before_speech_end:
            return dict(
                id=speech["index"],
                speaker=speech["speaker"],
                location=speech["location"],
            )

    return None

# %%
def thuc_to_table():
    """
    See https://mycapytain.readthedocs.io/en/latest/MyCapytain.local.html
    for a fuller example.
    """
    with open("./tei_primary_sources/tlg0003.tlg001.perseus-grc2.xml") as f:
        # We initiate a Text object giving the IO instance to resource argument
        text = CapitainsCtsText(resource=f)

    refs = [r[0] for r in text.getReffs(level=len(text.citation))]
    passages = [
        text.getTextualNode(subreference=ref, simple=True).export(
            Mimetypes.PLAINTEXT, exclude=["tei:note"]
        )
        for ref in refs
    ]
    refs = [list(map(lambda i: int(i), r.split("."))) for r in refs]
    speeches = [get_speech_for_ref(ref) for ref in refs]
    speech_ids = [s["id"] if s is not None else None for s in speeches]
    speakers = [s["speaker"] if s is not None else None for s in speeches]
    locations = [s["location"] if s is not None else None for s in speeches]

    return pl.DataFrame(
        {
            "reference": refs,
            "passage": passages,
            "speaker": speakers,
            "speech_id": speech_ids,
            "location": locations,
        }
    )

# %%
def save_df(df: pl.DataFrame) -> pl.DataFrame:
    df = thuc_to_table().with_columns(
        pl.col("passage")
        .map_elements(lambda p: spacy.tokens.DocBin(docs=[nlp(p)]).to_bytes())
        .alias("parsed_passage")
    )

    df.write_parquet(THUCYDIDES_PARQUET)

# %%
## START HERE

def restore_df():
    return pl.read_parquet(THUCYDIDES_PARQUET).with_columns(
        pl.col("parsed_passage").map_elements(
            lambda p: list(spacy.tokens.DocBin().from_bytes(p).get_docs(nlp.vocab))[0],
            return_dtype=pl.Object,
        )
    )

# %%
df = restore_df()

# %%
for token in df['parsed_passage'][1]:
    print((token, token.lemma_, token.pos_, token.dep_, token.morph.to_dict()))
# Out:
# (κίνησις, 'κίνησις', 'NOUN', 'nsubj', {'Case': 'Nom', 'Gender': 'Fem', 'Number': 'Sing'})
# (γὰρ, 'γάρ', 'ADV', 'discourse', {})
# (αὕτη, 'οὗτος', 'DET', 'det', {'Case': 'Nom', 'Gender': 'Fem', 'Number': 'Sing'})
# (μεγίστη, 'μέγας', 'ADJ', 'amod', {'Case': 'Nom', 'Degree': 'Pos', 'Gender': 'Fem', 'Number': 'Sing'})
# (δὴ, 'δή', 'ADV', 'discourse', {})
# (τοῖς, 'ὁ', 'DET', 'det', {'Case': 'Dat', 'Definite': 'Def', 'Gender': 'Masc', 'Number': 'Plur', 'PronType': 'Dem'})
# (Ἕλλησιν, 'Ἕλλην', 'NOUN', 'iobj', {'Case': 'Dat', 'Gender': 'Masc', 'Number': 'Plur'})
# (ἐγένετο, 'γίγνομαι', 'VERB', 'ROOT', {'Aspect': 'Perf', 'Mood': 'Ind', 'Number': 'Sing', 'Person': '3', 'Tense': 'Past', 'VerbForm': 'Fin', 'Voice': 'Mid'})
# (καὶ, 'καί', 'CCONJ', 'cc', {})
# (μέρει, 'μέρος', 'NOUN', 'conj', {'Case': 'Dat', 'Gender': 'Neut', 'Number': 'Sing'})
# (τινὶ, 'τίς', 'DET', 'det', {'Case': 'Dat', 'Gender': 'Masc', 'Number': 'Sing'})
# (τῶν, 'ὁ', 'DET', 'det', {'Case': 'Gen', 'Definite': 'Def', 'Gender': 'Masc', 'Number': 'Plur', 'PronType': 'Dem'})
# (βαρβάρων, 'βάρβαρος', 'NOUN', 'nmod', {'Case': 'Gen', 'Gender': 'Masc', 'Number': 'Plur'})
# (,, ',', 'PUNCT', 'dep', {})
# (ὡς, 'ὡς', 'ADV', 'dep', {'PronType': 'Rel'})
# (δὲ, 'δέ', 'ADV', 'discourse', {})
# (
#  , '\n ', 'CCONJ', 'ROOT', {})
# (εἰπεῖν, 'λέγω', 'VERB', 'ROOT', {'Aspect': 'Perf', 'Tense': 'Past', 'VerbForm': 'Inf', 'Voice': 'Act'})
# (καὶ, 'καί', 'ADV', 'advmod', {})
# (ἐπὶ, 'ἐπί', 'ADP', 'case', {})
# (πλεῖστον, 'πολύς', 'ADJ', 'obl', {'Case': 'Acc', 'Degree': 'Sup', 'Gender': 'Neut', 'Number': 'Sing'})
# (ἀνθρώπων, 'ἄνθρωπος', 'NOUN', 'nmod', {'Case': 'Gen', 'Gender': 'Masc', 'Number': 'Plur'})
# (., '.', 'PUNCT', 'ROOT', {})

# %%
from spacy import tokens as spacy_tokens

def count_finite_potential_optatives(tokens: list[spacy_tokens.Token]) -> int:
    n_potential_optatives = 0

    for token in tokens:
        if (
            token.pos_ == "VERB"
            and token.morph.to_dict().get("Mood") == "Opt"
            and "ἄν" in [t.lemma_ for t in token.children]
        ):
            n_potential_optatives += 1

    return n_potential_optatives

def count_possible_participial_potential_optatives(tokens: list[spacy_tokens.Token]) -> int:
    n_optatives = 0

    for token in tokens:
        if (
            token.pos_ == "VERB"
            and token.morph.to_dict().get("VerbForm") == "Part"
            and "ἄν" in [t.lemma_ for t in token.children]
        ):
            n_optatives += 1

    return n_optatives


def count_possible_infinitival_potential_optatives(tokens: list[spacy_tokens.Token]) -> int:
    n_optatives = 0

    for token in tokens:
        if (
            token.pos_ == "VERB"
            and token.morph.to_dict().get("VerbForm") == "Inf"
            and "ἄν" in [t.lemma_ for t in token.children]
        ):
            n_optatives += 1

    return n_optatives

df = df.with_columns(
    pl.col("parsed_passage").map_elements(
        count_finite_potential_optatives,
        return_dtype=pl.Int64
    ).alias("n_pot_opt"),
    pl.col("parsed_passage").map_elements(
        count_possible_participial_potential_optatives,
        return_dtype=pl.Int64
    ).alias("n?_part_opt"),
    pl.col("parsed_passage").map_elements(
        count_possible_infinitival_potential_optatives,
        return_dtype=pl.Int64
    ).alias("n?_inf_opt"),
)

# %%
df
# Out:
# shape: (3_587, 9)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ reference ┆ passage   ┆ speaker   ┆ speech_id ┆ … ┆ parsed_pa ┆ n_pot_opt ┆ n?_part_o ┆ n?_inf_o │
# │ ---       ┆ ---       ┆ ---       ┆ ---       ┆   ┆ ssage     ┆ ---       ┆ pt        ┆ pt       │
# │ list[i64] ┆ str       ┆ str       ┆ i64       ┆   ┆ ---       ┆ i64       ┆ ---       ┆ ---      │
# │           ┆           ┆           ┆           ┆   ┆ object    ┆           ┆ i64       ┆ i64      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ [1, 1, 1] ┆ Θουκυδίδη ┆ null      ┆ null      ┆ … ┆ Θουκυδίδη ┆ 0         ┆ 0         ┆ 0        │
# │           ┆ ς         ┆           ┆           ┆   ┆ ς         ┆           ┆           ┆          │
# │           ┆ Ἀθηναῖος  ┆           ┆           ┆   ┆ Ἀθηναῖος  ┆           ┆           ┆          │
# │           ┆ ξυνέγραψε ┆           ┆           ┆   ┆ ξυνέγραψε ┆           ┆           ┆          │
# │           ┆ …         ┆           ┆           ┆   ┆ …         ┆           ┆           ┆          │
# │ [1, 1, 2] ┆ κίνησις   ┆ null      ┆ null      ┆ … ┆ κίνησις   ┆ 0         ┆ 0         ┆ 0        │
# │           ┆ γὰρ αὕτη  ┆           ┆           ┆   ┆ γὰρ αὕτη  ┆           ┆           ┆          │
# │           ┆ μεγίστη   ┆           ┆           ┆   ┆ μεγίστη   ┆           ┆           ┆          │
# │           ┆ δὴ το…    ┆           ┆           ┆   ┆ δὴ το…    ┆           ┆           ┆          │
# │ [1, 1, 3] ┆ τὰ γὰρ    ┆ Thucydide ┆ 0         ┆ … ┆ τὰ γὰρ    ┆ 0         ┆ 0         ┆ 0        │
# │           ┆ πρὸ αὐτῶν ┆ s         ┆           ┆   ┆ πρὸ αὐτῶν ┆           ┆           ┆          │
# │           ┆ καὶ τὰ    ┆           ┆           ┆   ┆ καὶ τὰ    ┆           ┆           ┆          │
# │           ┆ ἔτι πα…   ┆           ┆           ┆   ┆ ἔτι πα…   ┆           ┆           ┆          │
# │ [1, 2, 1] ┆ φαίνεται  ┆ null      ┆ null      ┆ … ┆ φαίνεται  ┆ 0         ┆ 0         ┆ 0        │
# │           ┆ γὰρ ἡ νῦν ┆           ┆           ┆   ┆ γὰρ ἡ νῦν ┆           ┆           ┆          │
# │           ┆ Ἑλλὰς     ┆           ┆           ┆   ┆ Ἑλλὰς     ┆           ┆           ┆          │
# │           ┆ καλου…    ┆           ┆           ┆   ┆ καλου…    ┆           ┆           ┆          │
# │ [1, 2, 2] ┆ τῆς γὰρ   ┆ null      ┆ null      ┆ … ┆ τῆς γὰρ   ┆ 0         ┆ 1         ┆ 0        │
# │           ┆ ἐμπορίας  ┆           ┆           ┆   ┆ ἐμπορίας  ┆           ┆           ┆          │
# │           ┆ οὐκ       ┆           ┆           ┆   ┆ οὐκ       ┆           ┆           ┆          │
# │           ┆ οὔσης,    ┆           ┆           ┆   ┆ οὔσης,    ┆           ┆           ┆          │
# │           ┆ οὐ…       ┆           ┆           ┆   ┆ οὐ…       ┆           ┆           ┆          │
# │ …         ┆ …         ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …        │
# │ [8, 108,  ┆ καὶ ὁ Τισ ┆ null      ┆ null      ┆ … ┆ καὶ ὁ Τισ ┆ 0         ┆ 0         ┆ 0        │
# │ 3]        ┆ σαφέρνης  ┆           ┆           ┆   ┆ σαφέρνης  ┆           ┆           ┆          │
# │           ┆ ἀπὸ τῆς   ┆           ┆           ┆   ┆ ἀπὸ τῆς   ┆           ┆           ┆          │
# │           ┆ Ἀσπέ…     ┆           ┆           ┆   ┆ Ἀσπέ…     ┆           ┆           ┆          │
# │ [8, 108,  ┆ ὄντων δὲ  ┆ null      ┆ null      ┆ … ┆ ὄντων δὲ  ┆ 0         ┆ 0         ┆ 0        │
# │ 4]        ┆ τῶν Πελοπ ┆           ┆           ┆   ┆ τῶν Πελοπ ┆           ┆           ┆          │
# │           ┆ οννησίων  ┆           ┆           ┆   ┆ οννησίων  ┆           ┆           ┆          │
# │           ┆ ἐν …      ┆           ┆           ┆   ┆ ἐν …      ┆           ┆           ┆          │
# │ [8, 108,  ┆ φοβούμενο ┆ null      ┆ null      ┆ … ┆ φοβούμενο ┆ 0         ┆ 0         ┆ 0        │
# │ 5]        ┆ ι οὖν     ┆           ┆           ┆   ┆ ι οὖν     ┆           ┆           ┆          │
# │           ┆ αὐτὸν διὰ ┆           ┆           ┆   ┆ αὐτὸν διὰ ┆           ┆           ┆          │
# │           ┆ τοῦτο…    ┆           ┆           ┆   ┆ τοῦτο…    ┆           ┆           ┆          │
# │ [8, 109,  ┆ ὁ δὲ Τισσ ┆ null      ┆ null      ┆ … ┆ ὁ δὲ Τισσ ┆ 0         ┆ 0         ┆ 0        │
# │ 1]        ┆ αφέρνης   ┆           ┆           ┆   ┆ αφέρνης   ┆           ┆           ┆          │
# │           ┆ αἰσθόμενο ┆           ┆           ┆   ┆ αἰσθόμενο ┆           ┆           ┆          │
# │           ┆ ς κ…      ┆           ┆           ┆   ┆ ς κ…      ┆           ┆           ┆          │
# │ [8, 109,  ┆ [ὅταν ὁ   ┆ null      ┆ null      ┆ … ┆ [ὅταν ὁ   ┆ 0         ┆ 0         ┆ 0        │
# │ 2]        ┆ μετὰ      ┆           ┆           ┆   ┆ μετὰ      ┆           ┆           ┆          │
# │           ┆ τοῦτο τὸ  ┆           ┆           ┆   ┆ τοῦτο τὸ  ┆           ┆           ┆          │
# │           ┆ θέρος χε… ┆           ┆           ┆   ┆ θέρος χε… ┆           ┆           ┆          │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %%
# pot. optatives in speeches
df.filter(pl.col("speech_id").is_not_null()).select("n_pot_opt", "n?_part_opt", "n?_inf_opt").sum()

# 134
# Out:
# shape: (1, 3)
# ┌───────────┬─────────────┬────────────┐
# │ n_pot_opt ┆ n?_part_opt ┆ n?_inf_opt │
# │ ---       ┆ ---         ┆ ---        │
# │ i64       ┆ i64         ┆ i64        │
# ╞═══════════╪═════════════╪════════════╡
# │ 81        ┆ 23          ┆ 30         │
# └───────────┴─────────────┴────────────┘

# %%
# total pot. optatives
df.select("n_pot_opt", "n?_part_opt", "n?_inf_opt").sum()
# 346
# Out:
# shape: (1, 3)
# ┌───────────┬─────────────┬────────────┐
# │ n_pot_opt ┆ n?_part_opt ┆ n?_inf_opt │
# │ ---       ┆ ---         ┆ ---        │
# │ i64       ┆ i64         ┆ i64        │
# ╞═══════════╪═════════════╪════════════╡
# │ 95        ┆ 47          ┆ 104        │
# └───────────┴─────────────┴────────────┘

# %%
# total verbs

df = df.with_columns(
  pl.col("parsed_passage").map_elements(
      lambda doc: sum(1 for token in doc if token.pos_ == "VERB"),
      return_dtype=pl.UInt32,
  ).alias("verb_count")
)

df["verb_count"].sum()

"""
So out of 26545 total verbs, 6596 (24.84%) of them appear in speeches.

Out of those 26,545, 346 (1.3%) might be potential optatives.

Of 19,949 verbs not in speeches, 212 (1.1%) might be potential optatives.

Of 6596 verbs in speeeches, 134 (2%) might be potential optatives.
"""
# Out:
# 26545

# %%
df.filter(pl.col("speech_id").is_not_null())["verb_count"].sum()
# Out:
# 6596

# %%
def tokens_df(df: pl.DataFrame) -> pl.DataFrame:
  rows = []
  for row in df.iter_rows(named=True):
      for token in row["parsed_passage"]:
          rows.append({
              "reference": row["reference"],
              "speech_id": row["speech_id"],
              "speaker": row["speaker"],
              "location": row["location"],
              "text": token.text,
              "lemma": token.lemma_,
              "pos": token.pos_,
              "dep": token.dep_,
              "morph": token.morph.to_dict(),
          })
  return pl.DataFrame(rows)

tokens = tokens_df(df)

# %%
dtm = (
  tokens
  .group_by("speech_id", "lemma")
  .agg(pl.len().alias("count"))
  .pivot(on="lemma", index="speech_id", values="count", aggregate_function="sum")
  .fill_null(0)
)

# %%
def clause_has_an(token):
  return any(t.text == "ἄν" for t in token.sent if t.head == token.head or t.head == token)

def is_potential_optative(token):
  return (
      token.morph.get("Mood") == ["Opt"]
      and (any(child.text == "ἄν" for child in token.children) or clause_has_an(token))
  )
    
word_counts = (
  tokens
  .filter(pl.col("speech_id").is_not_null(), pl.col("pos") != "PUNCT")
  .group_by("speech_id", "speaker", "location")
  .agg(pl.len().alias("totwords"))
)

optative_counts = (
  df
  .filter(pl.col("speech_id").is_not_null())
  .with_columns(
      pl.col("parsed_passage").map_elements(
          lambda doc: sum(1 for token in doc if is_potential_optative(token)),
          return_dtype=pl.UInt32,
      ).alias("absolute_freq")
  )
  .group_by("speech_id", "speaker", "location")
  .agg(pl.col("absolute_freq").sum())
)

# %%
optative_counts.sort("absolute_freq")
# Out:
# shape: (115, 4)
# ┌───────────┬────────────┬─────────────────┬───────────────┐
# │ speech_id ┆ speaker    ┆ location        ┆ absolute_freq │
# │ ---       ┆ ---        ┆ ---             ┆ ---           │
# │ i64       ┆ str        ┆ str             ┆ u32           │
# ╞═══════════╪════════════╪═════════════════╪═══════════════╡
# │ 78        ┆ Melians    ┆ Melos           ┆ 0             │
# │ 58        ┆ Brasidas   ┆ Northern-Greece ┆ 0             │
# │ 36        ┆ Phormio    ┆ Corinthian_Gulf ┆ 0             │
# │ 62        ┆ Thucydides ┆ NA              ┆ 0             │
# │ 81        ┆ Athenians  ┆ Melos           ┆ 0             │
# │ …         ┆ …          ┆ …               ┆ …             │
# │ 75        ┆ Athenians  ┆ Melos           ┆ 1             │
# │ 108       ┆ Alcibiades ┆ Camarina        ┆ 1             │
# │ 24        ┆ Pericles   ┆ Athens          ┆ 2             │
# │ 26        ┆ Pericles   ┆ funeral-oration ┆ 2             │
# │ 29        ┆ Pericles   ┆ plague          ┆ 3             │
# └───────────┴────────────┴─────────────────┴───────────────┘

# %%
overall_rate = optative_counts["absolute_freq"].sum() / word_counts["totwords"].sum()
# Out:
# ---------------------------------------------------------------------------
# ShapeError                                Traceback (most recent call last)
# Cell In[34], line 8
#       4   word_counts
#       5   .select("speech_id", "speaker", "location", "totwords")
#       6   .join(optative_counts, on=["speech_id", "speaker", "location"], how="left")
#       7   .fill_null({"absolute_freq": 0})
# ----> 8   .with_columns(
#       9       (pl.col("absolute_freq") / pl.col("totwords") * 1000).alias("rel_freq_per_1k"),
#      10       (overall_rate * pl.col("totwords")).alias("expected_freq"),
#      11   )
#
# File ~/code/writing/articles/2025-04-11_thucydidean-hedges/.venv/lib/python3.13/site-packages/polars/dataframe/frame.py:10515, in DataFrame.with_columns(self, *exprs, **named_exprs)
#   10511
#   10512         return (
#   10513             self.lazy()
#   10514             .with_columns(*exprs, **named_exprs)
# > 10515             .collect(optimizations=QueryOptFlags._eager())
#   10516         )
#
# File ~/code/writing/articles/2025-04-11_thucydidean-hedges/.venv/lib/python3.13/site-packages/polars/_utils/deprecation.py:97, in deprecate_streaming_parameter.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#      93         kwargs["engine"] = "in-memory"
#      95     del kwargs["streaming"]
# ---> 97 return function(*args, **kwargs)
#
# File ~/code/writing/articles/2025-04-11_thucydidean-hedges/.venv/lib/python3.13/site-packages/polars/lazyframe/opt_flags.py:343, in forward_old_opt_flags.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     340         optflags = cb(optflags, kwargs.pop(key))  # type: ignore[no-untyped-call,unused-ignore]
#     342 kwargs["optimizations"] = optflags
# --> 343 return function(*args, **kwargs)
#
# File ~/code/writing/articles/2025-04-11_thucydidean-hedges/.venv/lib/python3.13/site-packages/polars/lazyframe/frame.py:2510, in LazyFrame.collect(self, type_coercion, predicate_pushdown, projection_pushdown, simplify_expression, slice_pushdown, comm_subplan_elim, comm_subexpr_elim, cluster_with_columns, collapse_joins, no_optimization, engine, background, optimizations, **_kwargs)
#    2508 # Only for testing purposes
#    2509 callback = _kwargs.get("post_opt_callback", callback)
# -> 2510 return wrap_df(ldf.collect(engine, callback))
#
# ShapeError: expected struct fields to have given length. given = 1, field length = 115.
#
# This error occurred in the following expression:
# 	[({0}) * (col("totwords"))]
